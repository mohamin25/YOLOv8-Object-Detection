# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 793.7/793.7 kB 7.6 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %%
import os
from ultralytics import YOLO

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
ROOT_DIR = '/content/gdrive/MyDrive/Colab Notebooks/dataset3'
ROOT_DIR2 = '/content/gdrive/MyDrive/Colab Notebooks/yamlfile'

# %%
output_dir = '/content/gdrive/MyDrive/yolo_outputs'
os.makedirs(output_dir, exist_ok=True)
model = YOLO("yolov8n.yaml")
data_yaml_path = '/content/gdrive/MyDrive/Colab Notebooks/yamlfile/data.yaml'
results = model.train(data=data_yaml_path, epochs=100, project=output_dir, name='train_checkpoint', save=True, save_period=1)
# Out:
# Ultralytics YOLOv8.2.48 🚀 Python-3.10.12 torch-2.3.0+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
checkpoint_path = '/content/gdrive/MyDrive/yolo_outputs/train_checkpoint5/weights/last.pt'
data_yaml_path = '/content/gdrive/MyDrive/Colab Notebooks/yamlfile/data.yaml'

# this is for using trained model
# bestresult_path = '/content/drive/MyDrive/yolo_outputs/train_checkpoint5/weights/best.pt'
# model = YOLO(bestresult_path)

# %%
model = YOLO(checkpoint_path)
results = model.train(data=data_yaml_path, epochs=100, project='/content/gdrive/MyDrive/yolo_outputs', name='train7', resume=True, save=True, save_period=1)
# Out:
# Ultralytics YOLOv8.2.48 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
output_dir = '/content/gdrive/MyDrive/Colab Notebooks/val results'
val_results = model.val(data=data_yaml_path, project=output_dir, name='val_results')
# Out:
# Ultralytics YOLOv8.2.48 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3006623 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/gdrive/MyDrive/Colab Notebooks/dataset3/labels/train.cache... 363 images, 0 backgrounds, 0 corrupt: 100%|██████████| 363/363 [00:00<?, ?it/s]
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 12, len(boxes) = 2020. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 23/23 [00:11<00:00,  1.94it/s]
#                    all        363       2020      0.947      0.881      0.949      0.568
#                biscuit        327        576      0.935      0.872      0.945      0.549
# ...

# %%
output_dir2 = '/content/gdrive/MyDrive/known'
test_image_dir = os.path.join('/content/gdrive/MyDrive/test images')
test_results = model.predict(source=test_image_dir, data=data_yaml_path, project=output_dir2, name='test_results', save=True, save_txt=True)
# Out:
# image 1/2 /content/gdrive/MyDrive/test images/{A67730CF-40CF-4CF8-A008-DEAFAA102278}.png.jpg: 544x640 1 biscuit, 1 box, 1 can, 1 mobile, 1 mouse, 67.4ms
# image 2/2 /content/gdrive/MyDrive/test images/{D5DB3E1E-284D-416B-B037-DD86869785CF}.png.jpg: 576x640 2 biscuits, 2 boxs, 1 can, 1 mobile, 1 mouse, 62.9ms
# Speed: 3.0ms preprocess, 65.2ms inference, 1.4ms postprocess per image at shape (1, 3, 576, 640)
# Results saved to /content/gdrive/MyDrive/known/test_results
# 2 labels saved to /content/gdrive/MyDrive/known/test_results/labels

# %%
video_path = '/content/gdrive/MyDrive/vid/testvideo.mp4.webm'
results = model.predict(source=video_path, save=True, project='/content/gdrive/MyDrive/yolo_outputs', name='video_predictions')
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/312) /content/gdrive/MyDrive/vid/testvideo.mp4.webm: 544x640 2 biscuits, 1 box, 1 can, 1 mobile, 1 mouse, 12.5ms
# video 1/1 (frame 2/312) /content/gdrive/MyDrive/vid/testvideo.mp4.webm: 544x640 2 biscuits, 1 box, 1 can, 1 mobile, 9.0ms
# video 1/1 (frame 3/312) /content/gdrive/MyDrive/vid/testvideo.mp4.webm: 544x640 2 biscuits, 1 box, 1 can, 1 mobile, 7.1ms
# ...
